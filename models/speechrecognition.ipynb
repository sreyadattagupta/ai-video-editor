# %%
# !pip install librosa
# Out:
# ...
#    ---------------------------------------- 0.0/260.7 kB ? eta -:--:--
#    ---------- ----------------------------- 71.7/260.7 kB 1.3 MB/s eta 0:00:01
#    ------------------------------- -------- 204.8/260.7 kB 2.5 MB/s eta 0:00:01
#    ---------------------------------------- 260.7/260.7 kB 2.0 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/71.6 kB ? eta -:--:--
#    ---------------------------------------- 71.6/71.6 kB 3.8 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/2.7 MB 8.3 MB/s eta 0:00:01
#    ------- -------------------------------- 0.5/2.7 MB 8.4 MB/s eta 0:00:01
#    --------- ------------------------------ 0.7/2.7 MB 5.2 MB/s eta 0:00:01
#    ---------- ----------------------------- 0.7/2.7 MB 4.9 MB/s eta 0:00:01
#    --------------- ------------------------ 1.1/2.7 MB 4.8 MB/s eta 0:00:01
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
